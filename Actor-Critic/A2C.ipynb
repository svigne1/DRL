# %% [markdown]
# # A2C, Advantage Actor Critic
#
# We are using a Advantage Actor Critic which <br/>
# - Uses **Bootstrapped** estimates for it's critcs' targets. And NOT Monte-Carlo estimates.
# - Takes a batch of gradients for training, NO parallelism in sampling or Asynchronuous sampling.
# - Has a **seperate network** for Actor and Critic. No weight sharing between the networks.
# - Simple **1-step return** as the Advantage (Bias). Not n-step (n = length of episode) where the critic is used for estimating only the baseline (Variance) or average of many n-step returns - GAE, where we take a bias-variance trade-off

# %% [markdown]
# ## Step 1: Imports

# %%
import gym
import tensorflow as tf
from tensorflow import keras
import numpy as np
import datetime as dt
import math

# %% [markdown]
# ## Step 2: Environment

# %%
GAMMA = 0.99

env = gym.make("CartPole-v0")
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

print("state",state_size, "action", action_size)

STORE_PATH = '/Users/SV/Desktop/Lyra/CS285/Actor-Critic'
logger = tf.summary.create_file_writer(STORE_PATH + f"/AC-CartPole_{dt.datetime.now().strftime('%d%m%Y%H%M')}")
# Out:
# state 4 action 2

# %% [markdown]
# ## Step 3: Network

# %%
actor = keras.Sequential([
    keras.layers.Dense(30, activation='relu', kernel_initializer=keras.initializers.he_normal()),
    keras.layers.Dense(30, activation='relu', kernel_initializer=keras.initializers.he_normal()),
    keras.layers.Dense(action_size, activation='softmax')
])

critic = keras.Sequential([
    keras.layers.Dense(30, activation='relu', kernel_initializer=keras.initializers.he_normal()),
    keras.layers.Dense(30, activation='relu', kernel_initializer=keras.initializers.he_normal()),
    keras.layers.Dense(1)
])

# %% [markdown]
# ## Step 4: Sample Action

# %%
# Since only one state is there, N = 1 in the mini-batch.
# And index 0, gives the value for that state.     

def sample_action(state):
    softmax_out = actor(state.reshape((1, -1)))
    selected_action = np.random.choice(action_size, p=softmax_out.numpy()[0])
    return selected_action

# %% [markdown]
# ## Step 5: Sample Episode

# %%
def get_rewards2go(raw_rewards):
    reward_sum = 0
    result = []
    for reward in reversed(raw_rewards):
        reward_sum = reward + GAMMA * reward_sum
        result.append(reward_sum)
        result.reverse()
    return result

def sample_episode(states, next_states, rewards, rewards2go, actions):
    state = env.reset()
    raw_rewards = []
    while True:
        action = sample_action(state)
        next_state, reward, done, _ = env.step(action)
        
        states.append(state)
        next_states.append(next_state)
        actions.append(action)
        raw_rewards.append(reward)
        state = next_state        
        
        if done:
            rewards.extend(raw_rewards)
            rewards2go.extend(get_rewards2go(raw_rewards))
            break

# %% [markdown]
# ## Step 6: Training

# %%
sample_size = 15000
batch_size = 5120
steps = 1000

actor_optimizer = tf.keras.optimizers.Adam(lr=0.001)

def averageGradients(grads, N):
    for i in range(len(grads)):
        grads[i] = grads[i]/N
        
def addGradients(grads, batch_grads):
    sum_grad = []
    for (grad, batch_grad) in zip(grads, batch_grads):
        sum_grad.append(grad + batch_grad)
    return sum_grad

def generate_sample_batcher(states, next_states, rewards, rewards2go, actions):
    states = np.array(states)
    next_states = np.array(next_states)
    rewards = np.array(rewards)
    rewards2go = np.array(rewards2go)
    actions = np.array(actions)
    
    # Policy Gradients     
    baseline = np.mean(rewards2go)
    rewards2go = rewards2go - baseline
    
    def sample_batcher(n):
        return states[n:n+batch_size], next_states[n:n+batch_size], rewards[n:n+batch_size], rewards2go[n:n+batch_size], actions[n:n+batch_size]

    return sample_batcher
    
for step in range(steps):

    # This is one gradient step    

    # Numpy arrays are immutable. 
    # So these NEED to be python lists.
    # Once sampled, u can convert them into np arrays
    rewards = []
    rewards2go = []
    states = []
    actions = []
    next_states = []

    N = 0 
    while(len(states) < sample_size):
        sample_episode(states, next_states, rewards, rewards2go, actions)
        N += 1
        if(N%10 == 0):
            print("Sampling Episode - ", N)
    print("Sampled", N, "Episodes")

    avg_reward = np.sum(rewards) / N    
    bat_per_epoch = math.floor(len(states) / batch_size)
    sample_batcher = generate_sample_batcher(states, next_states, rewards, rewards2go, actions)
    
    ###### Train Critic ######
    
#     # NEW optimizer for each policy to forget old policy's gradients.
#     critic_optimizer = tf.keras.optimizers.Adam(lr=0.001)
    
#     # @t1, fit critic, rest of the time, take a single gradient-step     
#     epoch = 300
#     if step != 0:
#         epoch = 4
        
#     for j in range(epoch):
        
#         gradients = None
#         loss = 0 
#         for i in range(bat_per_epoch): 
            
#             # Sample a batch sequentially not randomnly             
#             n = i*batch_size
#             batch_states, batch_next_states, batch_rewards, batch_rewards2go, batch_actions = sample_batcher(n)            
            
#             # Target for critic             
#             # @t1, Monte-Carlo estimates, rest of the time, Bootstrapped rewards.
#             y_true = batch_rewards2go
#             if step != 0:
#                 y_true = batch_rewards + GAMMA * np.squeeze(critic(batch_next_states))
            
#             with tf.GradientTape() as tape:

#                 # Squeeze is to remove dimension of size 1                 
#                 # if we use np.squeeze, automatic differentiation wont work
#                 y_pred = tf.squeeze(critic(batch_states)) 
                    
#                 batch_loss = tf.keras.losses.MSE(y_true=y_true, y_pred=y_pred)
                
#             batch_gradients = tape.gradient(batch_loss, critic.trainable_variables)
#             loss += batch_loss
            
#             # Sum the Gradients over all batches
#             if gradients is None:
#                 gradients = batch_gradients
#             else:
#                 gradients = addGradients(gradients, batch_gradients)
                
#         critic_optimizer.apply_gradients(zip(gradients, critic.trainable_variables))  
#         if j%10 == 0:
#             print(f"Training critic for {j+1} epochs ", loss)

    ###### Train Actor ######
    
    # For Policy Gradients
    
    gradients = None
    for i in range(bat_per_epoch):
        n = i*batch_size
        batch_states, batch_next_states, batch_rewards, batch_rewards2go, batch_actions = sample_batcher(n)
        
        with tf.GradientTape() as tape:
            predictions = actor(batch_states)
            batch_loss = tf.keras.losses.sparse_categorical_crossentropy(y_true=batch_actions, y_pred=predictions, from_logits=False)

            # For Actor-Critic
#             advantage = batch_rewards + GAMMA * np.squeeze(critic(batch_next_states)) - np.squeeze(critic(batch_states))
#             batch_loss = batch_loss * advantage

            # For Polciy Gradients
            batch_loss = batch_loss * batch_rewards2go
            
        batch_gradients = tape.gradient(batch_loss, actor.trainable_variables)

        # Sum the Gradients over all batches
        if gradients is None:
            gradients = batch_gradients
        else:
            gradients = addGradients(gradients, batch_gradients)

    # For Polciy Gradients
    averageGradients(gradients, N)
    actor_optimizer.apply_gradients(zip(gradients, actor.trainable_variables))     

    if step % 100 == 0:
        print("Saving model, actor & critic @ timestep", step)
        actor.save_weights(STORE_PATH + f"/actor{dt.datetime.now().strftime('%d%m%Y%H%M')}")
        # For Actor-Critic
        # critic.save_weights(STORE_PATH + f"/critic{dt.datetime.now().strftime('%d%m%Y%H%M')}")

    print(f"Step: {step}, AvgReward: {avg_reward}, step: {step}")
    with logger.as_default():
            tf.summary.scalar('avgReward', avg_reward, step=step)
# Out:
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampling Episode -  390
# Sampling Episode -  400
# Sampling Episode -  410
# Sampling Episode -  420
# Sampling Episode -  430
# Sampling Episode -  440
# Sampling Episode -  450
# Sampling Episode -  460
# Sampling Episode -  470
# Sampling Episode -  480
# Sampling Episode -  490
# Sampling Episode -  500
# Sampling Episode -  510
# Sampling Episode -  520
# Sampling Episode -  530
# Sampling Episode -  540
# Sampled 543 Episodes
# Saving model, actor & critic @ timestep 0
# Step: 0, AvgReward: 27.67587476979742, step: 0
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampling Episode -  390
# Sampling Episode -  400
# Sampling Episode -  410
# Sampling Episode -  420
# Sampling Episode -  430
# Sampling Episode -  440
# Sampling Episode -  450
# Sampling Episode -  460
# Sampling Episode -  470
# Sampling Episode -  480
# Sampling Episode -  490
# Sampling Episode -  500
# Sampling Episode -  510
# Sampled 518 Episodes
# Step: 1, AvgReward: 28.969111969111967, step: 1
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampling Episode -  390
# Sampling Episode -  400
# Sampling Episode -  410
# Sampling Episode -  420
# Sampling Episode -  430
# Sampling Episode -  440
# Sampling Episode -  450
# Sampling Episode -  460
# Sampling Episode -  470
# Sampling Episode -  480
# Sampling Episode -  490
# Sampled 497 Episodes
# Step: 2, AvgReward: 30.191146881287725, step: 2
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampling Episode -  390
# Sampling Episode -  400
# Sampling Episode -  410
# Sampling Episode -  420
# Sampling Episode -  430
# Sampling Episode -  440
# Sampling Episode -  450
# Sampling Episode -  460
# Sampled 464 Episodes
# Step: 3, AvgReward: 32.35129310344828, step: 3
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampling Episode -  390
# Sampling Episode -  400
# Sampling Episode -  410
# Sampling Episode -  420
# Sampling Episode -  430
# Sampling Episode -  440
# Sampling Episode -  450
# Sampling Episode -  460
# Sampled 466 Episodes
# Step: 4, AvgReward: 32.26394849785408, step: 4
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampling Episode -  390
# Sampling Episode -  400
# Sampling Episode -  410
# Sampling Episode -  420
# Sampling Episode -  430
# Sampling Episode -  440
# Sampling Episode -  450
# Sampled 450 Episodes
# Step: 5, AvgReward: 33.333333333333336, step: 5
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampling Episode -  390
# Sampling Episode -  400
# Sampling Episode -  410
# Sampling Episode -  420
# Sampling Episode -  430
# Sampling Episode -  440
# Sampled 442 Episodes
# Step: 6, AvgReward: 33.963800904977376, step: 6
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampling Episode -  390
# Sampling Episode -  400
# Sampling Episode -  410
# Sampling Episode -  420
# Sampling Episode -  430
# Sampled 438 Episodes
# Step: 7, AvgReward: 34.28538812785388, step: 7
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampling Episode -  390
# Sampling Episode -  400
# Sampling Episode -  410
# Sampling Episode -  420
# Sampled 424 Episodes
# Step: 8, AvgReward: 35.403301886792455, step: 8
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampling Episode -  390
# Sampling Episode -  400
# Sampled 405 Episodes
# Step: 9, AvgReward: 37.2, step: 9
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampling Episode -  390
# Sampling Episode -  400
# Sampling Episode -  410
# Sampling Episode -  420
# Sampled 427 Episodes
# Step: 10, AvgReward: 35.1615925058548, step: 10
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampling Episode -  390
# Sampling Episode -  400
# Sampling Episode -  410
# Sampled 415 Episodes
# Step: 11, AvgReward: 36.159036144578316, step: 11
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampled 382 Episodes
# Step: 12, AvgReward: 39.27748691099477, step: 12
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampling Episode -  390
# Sampling Episode -  400
# Sampled 401 Episodes
# Step: 13, AvgReward: 37.4788029925187, step: 13
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampling Episode -  390
# Sampling Episode -  400
# Sampled 400 Episodes
# Step: 14, AvgReward: 37.635, step: 14
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampling Episode -  390
# Sampled 392 Episodes
# Step: 15, AvgReward: 38.275510204081634, step: 15
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampling Episode -  390
# Sampling Episode -  400
# Sampled 405 Episodes
# Step: 16, AvgReward: 37.1679012345679, step: 16
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampled 386 Episodes
# Step: 17, AvgReward: 38.92227979274612, step: 17
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampled 376 Episodes
# Step: 18, AvgReward: 39.8936170212766, step: 18
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampling Episode -  380
# Sampled 388 Episodes
# Step: 19, AvgReward: 38.69072164948454, step: 19
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampling Episode -  370
# Sampled 370 Episodes
# Step: 20, AvgReward: 40.6027027027027, step: 20
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampled 360 Episodes
# Step: 21, AvgReward: 41.81944444444444, step: 21
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampled 364 Episodes
# Step: 22, AvgReward: 41.27472527472528, step: 22
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampled 349 Episodes
# Step: 23, AvgReward: 43.01146131805157, step: 23
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampled 349 Episodes
# Step: 24, AvgReward: 43.0, step: 24
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampled 362 Episodes
# Step: 25, AvgReward: 41.549723756906076, step: 25
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampled 347 Episodes
# Step: 26, AvgReward: 43.38040345821326, step: 26
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampling Episode -  360
# Sampled 362 Episodes
# Step: 27, AvgReward: 41.45303867403315, step: 27
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampled 359 Episodes
# Step: 28, AvgReward: 41.82729805013928, step: 28
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampled 335 Episodes
# Step: 29, AvgReward: 44.841791044776116, step: 29
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampled 340 Episodes
# Step: 30, AvgReward: 44.2, step: 30
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampled 332 Episodes
# Step: 31, AvgReward: 45.23795180722892, step: 31
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampling Episode -  350
# Sampled 356 Episodes
# Step: 32, AvgReward: 42.258426966292134, step: 32
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampled 333 Episodes
# Step: 33, AvgReward: 45.051051051051054, step: 33
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampled 337 Episodes
# Step: 34, AvgReward: 44.52225519287834, step: 34
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampled 330 Episodes
# Step: 35, AvgReward: 45.46666666666667, step: 35
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampled 332 Episodes
# Step: 36, AvgReward: 45.20180722891566, step: 36
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampled 330 Episodes
# Step: 37, AvgReward: 45.57878787878788, step: 37
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampled 332 Episodes
# Step: 38, AvgReward: 45.19879518072289, step: 38
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampled 328 Episodes
# Step: 39, AvgReward: 45.74390243902439, step: 39
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampling Episode -  340
# Sampled 342 Episodes
# Step: 40, AvgReward: 43.909356725146196, step: 40
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampled 333 Episodes
# Step: 41, AvgReward: 45.15615615615616, step: 41
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampled 327 Episodes
# Step: 42, AvgReward: 45.87767584097859, step: 42
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampled 321 Episodes
# Step: 43, AvgReward: 46.769470404984425, step: 43
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampled 320 Episodes
# Step: 44, AvgReward: 46.91875, step: 44
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampled 319 Episodes
# Step: 45, AvgReward: 47.23824451410658, step: 45
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampled 330 Episodes
# Step: 46, AvgReward: 45.512121212121215, step: 46
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampled 326 Episodes
# Step: 47, AvgReward: 46.04907975460123, step: 47
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampled 323 Episodes
# Step: 48, AvgReward: 46.56037151702786, step: 48
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampled 326 Episodes
# Step: 49, AvgReward: 46.0398773006135, step: 49
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# ...
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampled 325 Episodes
# Step: 71, AvgReward: 46.16, step: 71
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampling Episode -  330
# Sampled 333 Episodes
# Step: 72, AvgReward: 45.051051051051054, step: 72
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampled 311 Episodes
# Step: 73, AvgReward: 48.353697749196144, step: 73
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampled 318 Episodes
# Step: 74, AvgReward: 47.24842767295598, step: 74
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampled 314 Episodes
# Step: 75, AvgReward: 47.88535031847134, step: 75
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampled 319 Episodes
# Step: 76, AvgReward: 47.15987460815047, step: 76
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampled 312 Episodes
# Step: 77, AvgReward: 48.08974358974359, step: 77
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampled 320 Episodes
# Step: 78, AvgReward: 46.953125, step: 78
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampled 319 Episodes
# Step: 79, AvgReward: 47.043887147335425, step: 79
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampled 312 Episodes
# Step: 80, AvgReward: 48.166666666666664, step: 80
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampled 317 Episodes
# Step: 81, AvgReward: 47.397476340694006, step: 81
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampled 313 Episodes
# Step: 82, AvgReward: 47.92332268370607, step: 82
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampled 310 Episodes
# Step: 83, AvgReward: 48.39032258064516, step: 83
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampled 328 Episodes
# Step: 84, AvgReward: 45.78963414634146, step: 84
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampled 320 Episodes
# Step: 85, AvgReward: 46.959375, step: 85
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampled 319 Episodes
# Step: 86, AvgReward: 47.075235109717866, step: 86
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampled 309 Episodes
# Step: 87, AvgReward: 48.68608414239482, step: 87
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampled 311 Episodes
# Step: 88, AvgReward: 48.263665594855304, step: 88
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampled 321 Episodes
# Step: 89, AvgReward: 46.900311526479754, step: 89
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
# Sampling Episode -  170
# Sampling Episode -  180
# Sampling Episode -  190
# Sampling Episode -  200
# Sampling Episode -  210
# Sampling Episode -  220
# Sampling Episode -  230
# Sampling Episode -  240
# Sampling Episode -  250
# Sampling Episode -  260
# Sampling Episode -  270
# Sampling Episode -  280
# Sampling Episode -  290
# Sampling Episode -  300
# Sampling Episode -  310
# Sampling Episode -  320
# Sampled 328 Episodes
# Step: 90, AvgReward: 45.7469512195122, step: 90
# Sampling Episode -  10
# Sampling Episode -  20
# Sampling Episode -  30
# Sampling Episode -  40
# Sampling Episode -  50
# Sampling Episode -  60
# Sampling Episode -  70
# Sampling Episode -  80
# Sampling Episode -  90
# Sampling Episode -  100
# Sampling Episode -  110
# Sampling Episode -  120
# Sampling Episode -  130
# Sampling Episode -  140
# Sampling Episode -  150
# Sampling Episode -  160
